# %% [markdown]
# <a href="https://colab.research.google.com/github/SOUJU07/DSMP-Notebooks/blob/main/Copy_of_session_16_tasks.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ###`Q-1:` Write a program to create an empty series.

# %%
# code here
import numpy as np
import pandas as pd

empty_series=pd.Series([])
empty_series
# Out:
# Series([], dtype: object)

# %% [markdown]
# ###`Q-2:` Write a Pandas program to add, subtract, multiple and divide two Pandas Series.

# %%
# code here
first=pd.Series([1,2,3])
second=pd.Series([4,5,6])

add=first+second
sub=second-first
multiply=first*second
divide=first/second

# %% [markdown]
# ###`Q-3` Write a Pandas program to compare the elements of the two Pandas Series.
# Sample Series: [2, 4, 6, 8, 10], [1, 3, 5, 7, 10]

# %%
# code here

a=pd.Series([2,4,6,8,10])
b=pd.Series([1,3,5,7,10])

a[a>b]
# Out:
# 0    2
# 1    4
# 2    6
# 3    8
# dtype: int64

# %% [markdown]
# ###`Q-5.`Write a function to change the data type of given a column or a Series. Function takes series and data type as input, returns the converted series.
# ```
# series = pd.Series([1,2,'Python', 2.0, True, 100])
# change to float type data
# ```
# Note: Read about pd.to_numeric()

# %%
# code here
series = pd.Series([1,2,'Python', 2.0, True, 100])
pd.to_numeric(series,errors='coerce')
# Out:
# 0      1.0
# 1      2.0
# 2      NaN
# 3      2.0
# 4      1.0
# 5    100.0
# dtype: float64

# %% [markdown]
# Download data - https://drive.google.com/file/d/1LRhXwbEodeWXtzPhJCX0X9Lf_BECzvqb/view?usp=share_link
# All Batsman runs series in IPL 2008 to 2022.
#
# Below questions are based on this data.

# %% [markdown]
# ###`Q-6` Find top 10 most run getter from the series.

# %%
# code here
series=pd.read_csv('/content/batsman_runs_series (1).csv',index_col='batter').squeeze()
series.sort_values(ascending=False).head(10)
# Out:
# batter
# V Kohli           6634
# S Dhawan          6244
# DA Warner         5883
# RG Sharma         5881
# SK Raina          5536
# AB de Villiers    5181
# CH Gayle          4997
# MS Dhoni          4978
# RV Uthappa        4954
# KD Karthik        4377
# Name: batsman_run, dtype: int64

# %% [markdown]
# ###`Q-7` No of players having runs above 3000

# %%
# code here
series[series>3000]
# Out:
# batter
# AB de Villiers    5181
# AM Rahane         4074
# AT Rayudu         4190
# CH Gayle          4997
# DA Warner         5883
# F du Plessis      3403
# G Gambhir         4217
# KA Pollard        3437
# KD Karthik        4377
# KL Rahul          3895
# MK Pandey         3657
# MS Dhoni          4978
# RG Sharma         5881
# RV Uthappa        4954
# S Dhawan          6244
# SK Raina          5536
# SR Watson         3880
# SV Samson         3526
# V Kohli           6634
# YK Pathan         3222
# Name: batsman_run, dtype: int64

# %% [markdown]
# ###`Q-8` No of players having runs above mean value?

# %%
# code here
series[series>series.mean()]
# Out:
# batter
# A Symonds           974
# AB de Villiers     5181
# AC Gilchrist       2069
# AD Mathews          724
# AD Russell         2039
#                    ...
# WP Saha            2427
# Y Venugopal Rao     985
# YBK Jaiswal         547
# YK Pathan          3222
# Yuvraj Singh       2754
# Name: batsman_run, Length: 128, dtype: int64

# %% [markdown]
# Download data - https://drive.google.com/file/d/1QZuZ5bypUInfVvarHACLAi8tXXHvb8xd/view?usp=share_link
#
# file name - items.csv

# %% [markdown]
# ###`Q-9`
#     i. Read `items.csv` making `item_name` as index.
#     ii. Show no of nan values
#     ii. Item price is given in $, so convert it to rupees without currency symbol.
#     iii. Make data type of newly made series as float.
#     iv. Fill nan with mean of the series
#
#
# How csv file looks
#
# ```
# item_name	item_price
# Chips and Fresh Tomato Salsa	$2.39
# Izze	$3.39
# Nantucket Nectar	$3.39
# Chips and Tomatillo-Green Chili Salsa	$2.39
# Chicken Bowl	$16.98
#
# ```

# %%
# code here

series=pd.read_csv('/content/items (1).csv',index_col='item_name').squeeze()
series.head()
# Out:
# item_name
# Chips and Fresh Tomato Salsa              $2.39
# Izze                                      $3.39
# Nantucket Nectar                          $3.39
# Chips and Tomatillo-Green Chili Salsa     $2.39
# Chicken Bowl                             $16.98
# Name: item_price, dtype: object

# %%
series.isna().sum()
# Out:
# np.int64(50)

# %%
price_inr=pd.to_numeric(series.str.replace('$',''))*92
price_inr
# Out:
# item_name
# Chips and Fresh Tomato Salsa              219.88
# Izze                                      311.88
# Nantucket Nectar                          311.88
# Chips and Tomatillo-Green Chili Salsa     219.88
# Chicken Bowl                             1562.16
#                                           ...
# Steak Burrito                            1081.00
# Steak Burrito                            1081.00
# Chicken Salad Bowl                       1035.00
# Chicken Salad Bowl                        805.00
# Chicken Salad Bowl                        805.00
# Name: item_price, Length: 4622, dtype: float64

# %%
price_inr=price_inr.fillna(price_inr.mean())
price_inr.isna().sum()
# Out:
# np.int64(0)

# %% [markdown]
# ###`Q-10`:
#     i. Find mean price
#     ii. Find 30th and 6th percentile value
#     iii. Plot Histogram on price with bin size 50
#     iv. No of items price lies between [1000 to 2000]

# %%
# code here
price_inr.mean()
# Out:
# np.float64(686.5988976377954)

# %%
p30=price_inr.quantile(0.30)
p6=price_inr.quantile(0.06)
p100=price_inr.quantile(0.1)
print('30th percentile',p30)
print('6th percentile',p6)
print('100th percentile',p100)
# Out:
# 30th percentile 409.40000000000003
# 6th percentile 115.0
# 100th percentile 138.0

# %%
price_inr
# Out:
# item_name
# Chips and Fresh Tomato Salsa              219.88
# Izze                                      311.88
# Nantucket Nectar                          311.88
# Chips and Tomatillo-Green Chili Salsa     219.88
# Chicken Bowl                             1562.16
#                                           ...
# Steak Burrito                            1081.00
# Steak Burrito                            1081.00
# Chicken Salad Bowl                       1035.00
# Chicken Salad Bowl                        805.00
# Chicken Salad Bowl                        805.00
# Name: item_price, Length: 4622, dtype: float64

# %%
price_inr.plot(kind='hist',bins=50)
# Out:
# <Axes: ylabel='Frequency'>

# %%
price_inr[price_inr.between(1000,2000)]
# Out:
# item_name
# Chicken Bowl          1562.16
# Chicken Bowl          1010.16
# Steak Burrito         1081.00
# Chicken Bowl          1035.00
# Chicken Burrito       1010.16
#                        ...
# Steak Burrito         1081.00
# Veggie Burrito        1035.00
# Steak Burrito         1081.00
# Steak Burrito         1081.00
# Chicken Salad Bowl    1035.00
# Name: item_price, Length: 1066, dtype: float64
