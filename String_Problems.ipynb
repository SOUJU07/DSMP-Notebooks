# %% [markdown]
# <a href="https://colab.research.google.com/github/SOUJU07/DSMP-Notebooks/blob/main/String_Problems.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Find the length of a given string without using the len() function

s=input('enter a string')

counter=0

for i in s:
  counter+=1

print(counter)
# Out:
# enter a stringsoujanya
# 8

# %%
# Extract username from a given email.
# Eg if the email is nitish24singh@gmail.com
# then the username should be nitish24singh

email=input('enter your email')

pos=email.index('@')

username=email[0:pos]

print(username)
# Out:
# enter your emailsoujanya@gmail.com
# soujanya

# %%
# Count the frequency of a particular character in a provided string.
# Eg 'hello how are you' is the string, the frequency of h in this string is 2.

s=input('enter the string')
char=input('enter the character to search')

counter=0

for i in s:
  if i==char:
    counter+=1
print(counter)
# Out:
# enter the stringsoujanya
# enter the character to searcha
# 2

# %%
# Write a program which can remove a particular character from a string.

s=input('enter the string')
char=input('enter the character to remove')

l=''
for i in s:
  if char!=i:
    l=l+i
print(l)
# Out:
# enter the stringsoujanya kalita
# enter the character to removea
# soujny klit

# %%
# Write a program that can check whether a given string is palindrome or not.
# abba
# malayalam

s=input('enter a string')

flag=True
for i in range(len(s)//2):
  if s[i]!=s[len(s)-1-i]:
    flag=False
    print('Not palindrom')
    break

if flag:
  print('Palindrom')
# Out:
# enter a stringmalayalam
# Palindrom
